# %% [markdown]
# ## Classification Problem

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Independent and Dependent features
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head(20)
# Out:
# 0     setosa
# 1     setosa
# 2     setosa
# 3     setosa
# 4     setosa
# 5     setosa
# 6     setosa
# 7     setosa
# 8     setosa
# 9     setosa
# 10    setosa
# 11    setosa
# 12    setosa
# 13    setosa
# 14    setosa
# 15    setosa
# 16    setosa
# 17    setosa
# 18    setosa
# 19    setosa
# Name: species, dtype: object

# %%
# Train Test Split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
# Implement Random Forest classifier
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
# Prediction
y_pred=classifier.predict(X_test)

# %%
# Check Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,y_pred)

# %%
score
# Out:
# 0.9777777777777777

# %%
# Create a Pickle file  
import pickle
pickle_out = open("classifier.pkl","wb")
pickle.dump(classifier, pickle_out)
pickle_out.close()

# %%
import numpy as np

# %%
classifier.predict([[1,1,3,1]])
# Out:
# C:\Users\neenu\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['versicolor'], dtype=object)

# %%
pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\neenu\anaconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\neenu\anaconda3\lib\site-packages (from flask) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\neenu\anaconda3\lib\site-packages (from flask) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\neenu\anaconda3\lib\site-packages (from flask) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\neenu\anaconda3\lib\site-packages (from flask) (2.11.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\neenu\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask) (1.1.1)

# %%
pip install gunicorn
# Out:
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: setuptools>=3.0 in c:\users\neenu\anaconda3\lib\site-packages (from gunicorn) (50.3.1.post20201107)
# Installing collected packages: gunicorn
# Successfully installed gunicorn-20.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                            VersionNote: you may need to restart the kernel to use updated packages.
# ---------------------------------- -------------------
# absl-py                            1.0.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.10.0
# anaconda-project                   0.8.3
# analytics-python                   1.4.0
# anyio                              3.5.0
# AnyQt                              0.0.10
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.4.2
# astropy                            4.0.2
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.4
# Babel                              2.8.1
# backcall                           0.2.0
# backoff                            1.10.0
#
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# baycomp                            1.0.2
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.6.1
# bkcharts                           0.2
# bleach                             3.2.1
# blis                               0.7.5
# bokeh                              2.2.3
# Boruta                             0.3
# boto                               2.49.0
# Bottleneck                         1.3.2
# branca                             0.4.2
# brotlipy                           0.7.0
# CacheControl                       0.12.6
# cachetools                         5.0.0
# catalogue                          2.0.6
# certifi                            2020.6.20
# cffi                               1.14.3
# chardet                            3.0.4
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# commonmark                         0.9.1
# comtypes                           1.1.7
# conda                              4.13.0
# conda-build                        3.20.5
# conda-package-handling             1.7.2
# conda-verify                       3.4.2
# confuse                            1.4.0
# contextlib2                        0.6.0.post1
# cryptography                       3.1.1
# cv2-plt-imshow                     0.0.1
# cycler                             0.10.0
# cymem                              2.0.6
# Cython                             0.29.17
# cytoolz                            0.11.0
# dask                               2.30.0
# decorator                          4.4.2
# defusedxml                         0.6.0
# dictdiffer                         0.8.0
# diff-match-patch                   20200713
# distributed                        2.30.1
# docutils                           0.16
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.8.4
# flasgger                           0.9.5
# Flask                              1.1.2
# flatbuffers                        2.0
# folium                             0.12.1
# frozendict                         1.2
# fsspec                             0.8.3
# future                             0.18.2
# gast                               0.5.3
# gevent                             20.9.0
# glob2                              0.7
# google-auth                        2.6.0
# google-auth-oauthlib               0.4.6
# google-pasta                       0.2.0
# greenlet                           0.4.17
# grpcio                             1.43.0
# gunicorn                           20.1.0
# h11                                0.9.0
# h2                                 4.0.0
# h5py                               2.10.0
# HeapDict                           1.0.1
# hpack                              3.0.0
# html5lib                           1.1
# htmlmin                            0.1.12
# httpcore                           0.12.3
# httpx                              0.16.1
# hyperframe                         5.2.0
# idna                               2.10
# ImageHash                          4.2.0
# imageio                            2.9.0
# imagesize                          1.2.0
# imbalanced-learn                   0.7.0
# importlib-metadata                 4.10.1
# importlib-resources                5.2.2
# imutils                            0.5.4
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.19.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              5.6.4
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.1
# Jinja2                             2.11.2
# joblib                             0.17.0
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.7
# jupyter-console                    6.2.0
# jupyter-core                       4.6.3
# jupyterlab                         2.2.6
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  1.2.0
# jupyterlab-widgets                 1.0.0
# keras                              2.8.0
# keras-models                       0.0.7
# Keras-Preprocessing                1.1.2
# keyring                            21.4.0
# keyrings.alt                       4.0.2
# kiwisolver                         1.3.0
# langcodes                          3.3.0
# lazy-object-proxy                  1.4.3
# libarchive-c                       2.9
# libclang                           13.0.0
# llvmlite                           0.34.0
# locket                             0.2.0
# lockfile                           0.12.2
# lxml                               4.6.1
# Markdown                           3.3.6
# MarkupSafe                         1.1.1
# matplotlib                         3.3.2
# mccabe                             0.6.1
# menuinst                           1.4.16
# missingno                          0.4.2
# mistune                            0.8.4
# mitoinstaller                      0.0.107
# mitosheet                          0.1.379
# mkl-fft                            1.2.0
# mkl-random                         1.1.1
# mkl-service                        2.3.0
# mlxtend                            0.18.0
# mock                               4.0.2
# monotonic                          1.6
# more-itertools                     8.6.0
# mpmath                             1.1.0
# msgpack                            1.0.0
# multipledispatch                   0.6.0
# murmurhash                         1.0.6
# mysql-connector-python             8.0.23
# navigator-updater                  0.2.1
# nbclient                           0.5.1
# nbconvert                          6.0.7
# nbformat                           5.0.8
# nest-asyncio                       1.4.2
# networkx                           2.5
# nltk                               3.5
# nose                               1.3.7
# notebook                           6.1.4
# numba                              0.51.2
# numexpr                            2.7.1
# numpy                              1.22.2
# numpydoc                           1.1.0
# oauthlib                           3.2.0
# olefile                            0.46
# opencv-python                      4.5.5.62
# openpyxl                           3.0.5
# openTSNE                           0.4.3
# opt-einsum                         3.3.0
# orange-canvas-core                 0.1.15
# orange-widget-base                 4.7.0
# Orange3                            3.26.0
# packaging                          20.4
# pandas                             1.1.3
# pandas-profiling                   2.10.0
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.7.0
# partd                              1.1.0
# path                               15.0.0
# pathlib                            1.0.1
# pathlib2                           2.3.5
# pathtools                          0.1.2
# pathy                              0.6.1
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# phik                               0.11.0
# pickleshare                        0.7.5
# Pillow                             8.0.1
# pip                                20.2.4
# pkginfo                            1.6.1
# plotly                             5.3.0
# pluggy                             0.13.1
# ply                                3.11
# pmdarima                           1.8.0
# preshed                            3.0.6
# prometheus-client                  0.8.0
# prompt-toolkit                     3.0.8
# protobuf                           3.19.4
# psutil                             5.7.2
# py                                 1.9.0
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydantic                           1.8.2
# pydocstyle                         5.1.1
# pydotplus                          2.0.2
# pyee                               7.0.4
# pyflakes                           2.2.0
# Pygments                           2.7.2
# pyknow                             1.7.0
# pylint                             2.6.0
# PyNaCl                             1.4.0
# pynndescent                        0.4.8
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          19.1.0
# pyparsing                          2.4.7
# pyppeteer                          0.2.2
# pyqtgraph                          0.11.0
# pyreadline                         2.1
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             0.0.0
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.35.1
# python-louvain                     0.15
# pytz                               2020.1
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.3.1
# pyzmq                              19.0.2
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.1
# qtconsole                          4.7.7
# QtPy                               1.9.0
# regex                              2020.10.15
# requests                           2.24.0
# requests-oauthlib                  1.3.1
# retrying                           1.3.3
# rfc3986                            1.4.0
# rope                               0.18.0
# rsa                                4.8
# Rtree                              0.9.4
# ruamel-yaml                        0.15.87
# schema                             0.6.7
# scikit-image                       0.17.2
# scikit-learn                       1.0.2
# scikit-surprise                    1.1.1
# scipy                              1.5.2
# seaborn                            0.11.0
# Send2Trash                         1.5.0
# serverfiles                        0.3.1
# setuptools                         50.3.1.post20201107
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# sip                                4.19.13
# six                                1.15.0
# smart-open                         5.2.1
# sniffio                            1.1.0
# snowballstemmer                    2.0.0
# sortedcollections                  1.2.1
# sortedcontainers                   2.2.2
# soupsieve                          2.0.1
# spacy                              3.2.1
# spacy-legacy                       3.0.8
# spacy-loggers                      1.0.1
# Sphinx                             3.2.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.1.5
# spyder-kernels                     1.9.4
# SQLAlchemy                         1.3.20
# srsly                              2.4.2
# statsmodels                        0.12.2
# sweetviz                           2.1.3
# sympy                              1.6.2
# tables                             3.6.1
# tangled-up-in-unicode              0.0.6
# tblib                              1.7.0
# tenacity                           8.0.1
# tensorboard                        2.8.0
# tensorboard-data-server            0.6.1
# tensorboard-plugin-wit             1.8.1
# tensorflow                         2.8.0
# tensorflow-io-gcs-filesystem       0.24.0
# termcolor                          1.1.0
# terminado                          0.9.1
# testpath                           0.4.4
# tf-estimator-nightly               2.8.0.dev2021122109
# thinc                              8.0.13
# threadpoolctl                      2.1.0
# tifffile                           2020.10.1
# toml                               0.10.1
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.50.2
# traitlets                          5.0.5
# typer                              0.4.0
# typing-extensions                  3.7.4.3
# ujson                              4.0.1
# unicodecsv                         0.14.1
# urllib3                            1.25.11
# visions                            0.6.0
# wasabi                             0.9.0
# watchdog                           0.10.3
# wcwidth                            0.2.5
# webencodings                       0.5.1
# websocket-client                   1.2.3
# websockets                         8.1
# Werkzeug                           1.0.1
# wheel                              0.35.1
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wordcloud                          1.8.1
# wrapt                              1.11.2
# xlrd                               1.2.0
# XlsxWriter                         1.3.7
# xlwings                            0.20.8
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.30.0
# zict                               2.0.0
# zipp                               3.4.0
# zope.event                         4.5.0
# zope.interface                     5.1.2
